# %% [markdown]
# #**Stacked Ensemble Model**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score,accuracy_score,roc_curve,auc
from sklearn.model_selection import KFold

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **Reading Dataset from drive**

# %%
columns = ["ID", "Diagnosis", "radius1", "texture1", "perimeter1", "area1", "smoothness1", "compactness1", "concavity1", "concave_points1", "symmetry1", "fractal_dimension1", "radius2", "texture2", "perimeter2", "area2", "smoothness2", "compactness2", "concavity2", "concave_points2", "symmetry2", "fractal_dimension2", "radius3", "texture3", "perimeter3", "area3", "smoothness3", "compactness3", "concavity3", "concave_points3", "symmetry3", "fractal_dimension3"]

data = pd.read_csv('/content/drive/My Drive/Sem5/new_ml/a4/wdbc.data',header = None, names = columns)
target_col = "Diagnosis"

# %%
data.head()
# Out:
#          ID Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0    842302         M    17.99     10.38      122.80  1001.0      0.11840
# 1    842517         M    20.57     17.77      132.90  1326.0      0.08474
# 2  84300903         M    19.69     21.25      130.00  1203.0      0.10960
# 3  84348301         M    11.42     20.38       77.58   386.1      0.14250
# 4  84358402         M    20.29     14.34      135.10  1297.0      0.10030
#
#    compactness1  concavity1  concave_points1  ...  radius3  texture3  \
# 0       0.27760      0.3001          0.14710  ...    25.38     17.33
# 1       0.07864      0.0869          0.07017  ...    24.99     23.41
# 2       0.15990      0.1974          0.12790  ...    23.57     25.53
# 3       0.28390      0.2414          0.10520  ...    14.91     26.50
# 4       0.13280      0.1980          0.10430  ...    22.54     16.67
#
#    perimeter3   area3  smoothness3  compactness3  concavity3  concave_points3  \
# 0      184.60  2019.0       0.1622        0.6656      0.7119           0.2654
# 1      158.80  1956.0       0.1238        0.1866      0.2416           0.1860
# 2      152.50  1709.0       0.1444        0.4245      0.4504           0.2430
# 3       98.87   567.7       0.2098        0.8663      0.6869           0.2575
# 4      152.20  1575.0       0.1374        0.2050      0.4000           0.1625
#
#    symmetry3  fractal_dimension3
# 0     0.4601             0.11890
# 1     0.2750             0.08902
# 2     0.3613             0.08758
# 3     0.6638             0.17300
# 4     0.2364             0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# #**EDA**

# %% [markdown]
# **(i) Missing values**

# %%
data.isnull().sum()
# Out:
# ID                    0
# Diagnosis             0
# radius1               0
# texture1              0
# perimeter1            0
# area1                 0
# smoothness1           0
# compactness1          0
# concavity1            0
# concave_points1       0
# symmetry1             0
# fractal_dimension1    0
# radius2               0
# texture2              0
# perimeter2            0
# area2                 0
# smoothness2           0
# compactness2          0
# concavity2            0
# concave_points2       0
# symmetry2             0
# fractal_dimension2    0
# radius3               0
# texture3              0
# perimeter3            0
# area3                 0
# smoothness3           0
# compactness3          0
# concavity3            0
# concave_points3       0
# symmetry3             0
# fractal_dimension3    0
# dtype: int64

# %% [markdown]
# **(ii) Handle Outliers**

# %%
'''for col in data.columns:
  sns.boxplot(data[[col]])
  plt.tight_layout()
  plt.show()'''
# Out:
# 'for col in data.columns:\n  sns.boxplot(data[[col]])\n  plt.tight_layout()\n  plt.show()'

# %%
x = data.loc[:,data.columns!=target_col]
y = data.iloc[:,data.columns==target_col]

# %% [markdown]
# **(iv) Label encoding**

# %%
def double(val):
  if val == 'M':
    return 1

  return 0

y = pd.Series(list(map(double, list(y['Diagnosis']))))
#print(y)

# %%
x
# Out:
#            ID  radius1  texture1  perimeter1   area1  smoothness1  \
# 0      842302    17.99     10.38      122.80  1001.0      0.11840
# 1      842517    20.57     17.77      132.90  1326.0      0.08474
# 2    84300903    19.69     21.25      130.00  1203.0      0.10960
# 3    84348301    11.42     20.38       77.58   386.1      0.14250
# 4    84358402    20.29     14.34      135.10  1297.0      0.10030
# ..        ...      ...       ...         ...     ...          ...
# 564    926424    21.56     22.39      142.00  1479.0      0.11100
# 565    926682    20.13     28.25      131.20  1261.0      0.09780
# 566    926954    16.60     28.08      108.30   858.1      0.08455
# 567    927241    20.60     29.33      140.10  1265.0      0.11780
# 568     92751     7.76     24.54       47.92   181.0      0.05263
#
#      compactness1  concavity1  concave_points1  symmetry1  ...  radius3  \
# 0         0.27760     0.30010          0.14710     0.2419  ...   25.380
# 1         0.07864     0.08690          0.07017     0.1812  ...   24.990
# 2         0.15990     0.19740          0.12790     0.2069  ...   23.570
# 3         0.28390     0.24140          0.10520     0.2597  ...   14.910
# 4         0.13280     0.19800          0.10430     0.1809  ...   22.540
# ..            ...         ...              ...        ...  ...      ...
# 564       0.11590     0.24390          0.13890     0.1726  ...   25.450
# 565       0.10340     0.14400          0.09791     0.1752  ...   23.690
# 566       0.10230     0.09251          0.05302     0.1590  ...   18.980
# 567       0.27700     0.35140          0.15200     0.2397  ...   25.740
# 568       0.04362     0.00000          0.00000     0.1587  ...    9.456
#
#      texture3  perimeter3   area3  smoothness3  compactness3  concavity3  \
# 0       17.33      184.60  2019.0      0.16220       0.66560      0.7119
# 1       23.41      158.80  1956.0      0.12380       0.18660      0.2416
# 2       25.53      152.50  1709.0      0.14440       0.42450      0.4504
# 3       26.50       98.87   567.7      0.20980       0.86630      0.6869
# 4       16.67      152.20  1575.0      0.13740       0.20500      0.4000
# ..        ...         ...     ...          ...           ...         ...
# 564     26.40      166.10  2027.0      0.14100       0.21130      0.4107
# 565     38.25      155.00  1731.0      0.11660       0.19220      0.3215
# 566     34.12      126.70  1124.0      0.11390       0.30940      0.3403
# 567     39.42      184.60  1821.0      0.16500       0.86810      0.9387
# 568     30.37       59.16   268.6      0.08996       0.06444      0.0000
#
#      concave_points3  symmetry3  fractal_dimension3
# 0             0.2654     0.4601             0.11890
# 1             0.1860     0.2750             0.08902
# 2             0.2430     0.3613             0.08758
# 3             0.2575     0.6638             0.17300
# 4             0.1625     0.2364             0.07678
# ..               ...        ...                 ...
# 564           0.2216     0.2060             0.07115
# 565           0.1628     0.2572             0.06637
# 566           0.1418     0.2218             0.07820
# 567           0.2650     0.4087             0.12400
# 568           0.0000     0.2871             0.07039
#
# [569 rows x 31 columns]

# %%
'''for col in x.columns:
  Q1 = x[col].quantile(0.25)
  Q3 = x[col].quantile(0.75)
  IQR = Q3 - Q1
  low = Q1 - 1.5 * IQR
  high = Q3 + 1.5 * IQR

  x[col] = x[col].clip(low, high)'''
# Out:
# 'for col in x.columns:\n  Q1 = x[col].quantile(0.25)\n  Q3 = x[col].quantile(0.75)\n  IQR = Q3 - Q1\n  low = Q1 - 1.5 * IQR\n  high = Q3 + 1.5 * IQR\n\n  x[col] = x[col].clip(low, high)'

# %%
'''for col in x.columns:
  sns.boxplot(col)
  plt.tight_layout()
  plt.show()'''
# Out:
# 'for col in x.columns:\n  sns.boxplot(col)\n  plt.tight_layout()\n  plt.show()'

# %% [markdown]
# **(iii) Standarization / Normalization**

# %%
x.head()
# Out:
#          ID  radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0    842302    17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1    842517    20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2  84300903    19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3  84348301    11.42     20.38       77.58   386.1      0.14250       0.28390
# 4  84358402    20.29     14.34      135.10  1297.0      0.10030       0.13280
#
#    concavity1  concave_points1  symmetry1  ...  radius3  texture3  perimeter3  \
# 0      0.3001          0.14710     0.2419  ...    25.38     17.33      184.60
# 1      0.0869          0.07017     0.1812  ...    24.99     23.41      158.80
# 2      0.1974          0.12790     0.2069  ...    23.57     25.53      152.50
# 3      0.2414          0.10520     0.2597  ...    14.91     26.50       98.87
# 4      0.1980          0.10430     0.1809  ...    22.54     16.67      152.20
#
#     area3  smoothness3  compactness3  concavity3  concave_points3  symmetry3  \
# 0  2019.0       0.1622        0.6656      0.7119           0.2654     0.4601
# 1  1956.0       0.1238        0.1866      0.2416           0.1860     0.2750
# 2  1709.0       0.1444        0.4245      0.4504           0.2430     0.3613
# 3   567.7       0.2098        0.8663      0.6869           0.2575     0.6638
# 4  1575.0       0.1374        0.2050      0.4000           0.1625     0.2364
#
#    fractal_dimension3
# 0             0.11890
# 1             0.08902
# 2             0.08758
# 3             0.17300
# 4             0.07678
#
# [5 rows x 31 columns]

# %%
x_standard = x.copy()
standard = StandardScaler()

for col in x_standard.columns[1:]:
  x_standard[col] = standard.fit_transform(x_standard[[col]])

x_standard.head()
# Out:
#          ID   radius1  texture1  perimeter1     area1  smoothness1  \
# 0    842302  1.097064 -2.073335    1.269934  0.984375     1.568466
# 1    842517  1.829821 -0.353632    1.685955  1.908708    -0.826962
# 2  84300903  1.579888  0.456187    1.566503  1.558884     0.942210
# 3  84348301 -0.768909  0.253732   -0.592687 -0.764464     3.283553
# 4  84358402  1.750297 -1.151816    1.776573  1.826229     0.280372
#
#    compactness1  concavity1  concave_points1  symmetry1  ...   radius3  \
# 0      3.283515    2.652874         2.532475   2.217515  ...  1.886690
# 1     -0.487072   -0.023846         0.548144   0.001392  ...  1.805927
# 2      1.052926    1.363478         2.037231   0.939685  ...  1.511870
# 3      3.402909    1.915897         1.451707   2.867383  ... -0.281464
# 4      0.539340    1.371011         1.428493  -0.009560  ...  1.298575
#
#    texture3  perimeter3     area3  smoothness3  compactness3  concavity3  \
# 0 -1.359293    2.303601  2.001237     1.307686      2.616665    2.109526
# 1 -0.369203    1.535126  1.890489    -0.375612     -0.430444   -0.146749
# 2 -0.023974    1.347475  1.456285     0.527407      1.082932    0.854974
# 3  0.133984   -0.249939 -0.550021     3.394275      3.893397    1.989588
# 4 -1.466770    1.338539  1.220724     0.220556     -0.313395    0.613179
#
#    concave_points3  symmetry3  fractal_dimension3
# 0         2.296076   2.750622            1.937015
# 1         1.087084  -0.243890            0.281190
# 2         1.955000   1.152255            0.201391
# 3         2.175786   6.046041            4.935010
# 4         0.729259  -0.868353           -0.397100
#
# [5 rows x 31 columns]

# %%
x_norm = x.copy()
normalize = MinMaxScaler()

for col in x_norm.columns[1:]:
  x_norm[col] = normalize.fit_transform(x_norm[[col]])

x_norm.head()
# Out:
#          ID   radius1  texture1  perimeter1     area1  smoothness1  \
# 0    842302  0.521037  0.022658    0.545989  0.363733     0.593753
# 1    842517  0.643144  0.272574    0.615783  0.501591     0.289880
# 2  84300903  0.601496  0.390260    0.595743  0.449417     0.514309
# 3  84348301  0.210090  0.360839    0.233501  0.102906     0.811321
# 4  84358402  0.629893  0.156578    0.630986  0.489290     0.430351
#
#    compactness1  concavity1  concave_points1  symmetry1  ...   radius3  \
# 0      0.792037    0.703140         0.731113   0.686364  ...  0.620776
# 1      0.181768    0.203608         0.348757   0.379798  ...  0.606901
# 2      0.431017    0.462512         0.635686   0.509596  ...  0.556386
# 3      0.811361    0.565604         0.522863   0.776263  ...  0.248310
# 4      0.347893    0.463918         0.518390   0.378283  ...  0.519744
#
#    texture3  perimeter3     area3  smoothness3  compactness3  concavity3  \
# 0  0.141525    0.668310  0.450698     0.601136      0.619292    0.568610
# 1  0.303571    0.539818  0.435214     0.347553      0.154563    0.192971
# 2  0.360075    0.508442  0.374508     0.483590      0.385375    0.359744
# 3  0.385928    0.241347  0.094008     0.915472      0.814012    0.548642
# 4  0.123934    0.506948  0.341575     0.437364      0.172415    0.319489
#
#    concave_points3  symmetry3  fractal_dimension3
# 0         0.912027   0.598462            0.418864
# 1         0.639175   0.233590            0.222878
# 2         0.835052   0.403706            0.213433
# 3         0.884880   1.000000            0.773711
# 4         0.558419   0.157500            0.142595
#
# [5 rows x 31 columns]

# %% [markdown]
# #**Feature Engineering**

# %% [markdown]
# #**Splitting**

# %%
x_train,x_test,y_train,y_test = train_test_split(x_norm,y,test_size=0.5,random_state = 42)
x_val,x_test,y_val,y_test = train_test_split(x_test,y_test,test_size=0.2,random_state = 42)

# %%
print(x_train.shape,y_train.shape)
print(x_val.shape,y_val.shape)
print(x_test.shape,y_test.shape)
# Out:
# (284, 31) (284,)
# (228, 31) (228,)
# (57, 31) (57,)

# %% [markdown]
# #**Model Building**

# %% [markdown]
# #**Stacked Ensemble Model**

# %%
base_learners = [
    ("svm", SVC(probability=True, random_state=42)),
    ("nb", GaussianNB()),
    ("dt", DecisionTreeClassifier(random_state=42))
]

final_estimator = LogisticRegression(random_state=42)

model = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

model.fit(x_train,y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('svm', SVC(probability=True, random_state=42)),
#                                ('nb', GaussianNB()),
#                                ('dt', DecisionTreeClassifier(random_state=42))],
#                    final_estimator=LogisticRegression(random_state=42),
#                    n_jobs=-1)

# %%
y_pre_train = model.predict(x_train)
con_train_model = confusion_matrix(y_train,y_pre_train)

accuracy_model_train = accuracy_score(y_train,y_pre_train)
precision_model_train = precision_score(y_train,y_pre_train)
f1_model_train = f1_score(y_train,y_pre_train)
recall_model_train = recall_score(y_train,y_pre_train)

print("Accuracy Score of Training  :",accuracy_model_train)
print("Precision Score of Training :",precision_model_train)
print("F1 Score of Training        :",f1_model_train)
print("Recall Score of Training    :",recall_model_train)
print("\nConfusion Matrix :- \n",con_train_model)

sns.heatmap(con_train_model)
plt.show()
# Out:
# Accuracy Score of Training  : 1.0
# Precision Score of Training : 1.0
# F1 Score of Training        : 1.0
# Recall Score of Training    : 1.0
#
# Confusion Matrix :-
#  [[170   0]
#  [  0 114]]

# %% [markdown]
# **Parameters of the Model**

# %%
model.get_params()
# Out:
# {'cv': 5,
#  'estimators': [('svm', SVC(probability=True, random_state=42)),
#   ('nb', GaussianNB()),
#   ('dt', DecisionTreeClassifier(random_state=42))],
#  'final_estimator__C': 1.0,
#  'final_estimator__class_weight': None,
#  'final_estimator__dual': False,
#  'final_estimator__fit_intercept': True,
#  'final_estimator__intercept_scaling': 1,
#  'final_estimator__l1_ratio': None,
#  'final_estimator__max_iter': 100,
#  'final_estimator__multi_class': 'deprecated',
#  'final_estimator__n_jobs': None,
#  'final_estimator__penalty': 'l2',
#  'final_estimator__random_state': 42,
#  'final_estimator__solver': 'lbfgs',
#  'final_estimator__tol': 0.0001,
#  'final_estimator__verbose': 0,
#  'final_estimator__warm_start': False,
#  'final_estimator': LogisticRegression(random_state=42),
#  'n_jobs': -1,
#  'passthrough': False,
#  'stack_method': 'auto',
#  'verbose': 0,
#  'svm': SVC(probability=True, random_state=42),
#  'nb': GaussianNB(),
#  'dt': DecisionTreeClassifier(random_state=42),
#  'svm__C': 1.0,
#  'svm__break_ties': False,
#  'svm__cache_size': 200,
#  'svm__class_weight': None,
#  'svm__coef0': 0.0,
#  'svm__decision_function_shape': 'ovr',
#  'svm__degree': 3,
#  'svm__gamma': 'scale',
#  'svm__kernel': 'rbf',
#  'svm__max_iter': -1,
#  'svm__probability': True,
#  'svm__random_state': 42,
#  'svm__shrinking': True,
#  'svm__tol': 0.001,
#  'svm__verbose': False,
#  'nb__priors': None,
#  'nb__var_smoothing': 1e-09,
#  'dt__ccp_alpha': 0.0,
#  'dt__class_weight': None,
#  'dt__criterion': 'gini',
#  'dt__max_depth': None,
#  'dt__max_features': None,
#  'dt__max_leaf_nodes': None,
#  'dt__min_impurity_decrease': 0.0,
#  'dt__min_samples_leaf': 1,
#  'dt__min_samples_split': 2,
#  'dt__min_weight_fraction_leaf': 0.0,
#  'dt__monotonic_cst': None,
#  'dt__random_state': 42,
#  'dt__splitter': 'best'}

# %% [markdown]
# #**Grid Search CV**

# %% [markdown]
# **Case 1**

# %%
base_learners = [
    ("svm", SVC(probability=True, random_state=42)),
    ("nb", GaussianNB()),
    ("dt", DecisionTreeClassifier(random_state=42))
]

final_estimator = LogisticRegression(max_iter=500, random_state=42)

model1 = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

'''param_grid_case1 = {
    # SVM
    "svm__C": [0.1, 1, 10],
    "svm__kernel": ["linear", "rbf"],
    "svm__gamma": ["scale", "auto"],

    # Naive Bayes
    "nb__var_smoothing": [1e-9, 1e-8, 1e-7],

    # Decision Tree
    "dt__max_depth": [None, 5, 10],
    "dt__criterion": ["gini", "entropy"],

    # Logistic Regression (final estimator)
    "final_estimator__C": [0.01, 0.1, 1, 10],
    "final_estimator__penalty": ["l1", "l2"],
    "final_estimator__solver": ["liblinear", "saga"]
}'''

param_grid_case1 = {
    "svm__C": [0.1, 1],
    "svm__kernel": ["linear", "rbf"],
    "svm__gamma": ["scale"],

    "nb__var_smoothing": [1e-9, 1e-8],

    "dt__max_depth": [None, 10],
    "dt__criterion": ["gini"],

    "final_estimator__C": [0.1, 1, 10],
    "final_estimator__penalty": ["l2"],
    "final_estimator__solver": ["liblinear"]
}

grid = GridSearchCV(model1,param_grid = param_grid_case1, cv = 5)
grid.fit(x_val,y_val)
print(grid.best_params_)
print(grid.best_score_)

# %% [markdown]
# **Case 2**

# %%
final_estimator = RandomForestClassifier(random_state=42)

model2 = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

'''param_grid_case2 = {
    # SVM
    "svm__C": [0.1, 1, 10],
    "svm__kernel": ["linear", "rbf"],
    "svm__gamma": ["scale", "auto"],

    # Naive Bayes
    "nb__var_smoothing": [1e-9, 1e-8, 1e-7],

    # Decision Tree
    "dt__max_depth": [None, 5, 10],
    "dt__criterion": ["gini", "entropy"],

    # Random Forest (final estimator)
    "final_estimator__n_estimators": [100, 200, 500],
    "final_estimator__max_depth": [None, 10, 20],
    "final_estimator__min_samples_split": [2, 5, 10],
    "final_estimator__max_features": ["sqrt", "log2"]
}'''

param_grid_case2 = {
    "svm__C": [0.1, 1],
    "svm__kernel": ["rbf"],
    "svm__gamma": ["scale"],

    "nb__var_smoothing": [1e-9],

    "dt__max_depth": [None, 10],
    "dt__criterion": ["gini"],

    "final_estimator__n_estimators": [100, 300],
    "final_estimator__max_depth": [None, 20],
    "final_estimator__min_samples_split": [2, 5],
    "final_estimator__max_features": ["sqrt"]
}

grid = GridSearchCV(model2,param_grid = param_grid_case2, cv = 5)
grid.fit(x_val,y_val)
print(grid.best_params_)
print(grid.best_score_)

# %% [markdown]
# **Case 3**

# %%
base_learners_case3 = [
    ("svm", SVC(probability=True, random_state=42)),
    ("dt", DecisionTreeClassifier(random_state=42)),
    ("knn", KNeighborsClassifier())
]

final_estimator = LogisticRegression(max_iter=500, random_state=42)

model3 = StackingClassifier(
    estimators=base_learners_case3,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

'''param_grid_case3 = {
    # SVM
    "svm__C": [0.1, 1, 10],
    "svm__kernel": ["linear", "rbf"],
    "svm__gamma": ["scale", "auto"],

    # Decision Tree
    "dt__max_depth": [None, 5, 10],
    "dt__criterion": ["gini", "entropy"],

    # KNN
    "knn__n_neighbors": [3, 5, 7, 11],
    "knn__weights": ["uniform", "distance"],
    "knn__metric": ["euclidean", "manhattan"],

    # Logistic Regression (final estimator)
    "final_estimator__C": [0.01, 0.1, 1, 10],
    "final_estimator__penalty": ["l1", "l2"],
    "final_estimator__solver": ["liblinear", "saga"]
}'''

param_grid_case3 = {
    "svm__C": [0.1, 1],
    "svm__kernel": ["rbf"],
    "svm__gamma": ["scale"],

    "dt__max_depth": [None, 10],
    "dt__criterion": ["gini"],

    "knn__n_neighbors": [5, 11],
    "knn__weights": ["uniform", "distance"],
    "knn__metric": ["euclidean"],

    "final_estimator__C": [0.1, 1],
    "final_estimator__penalty": ["l2"],
    "final_estimator__solver": ["liblinear"]
}

grid = GridSearchCV(model3,param_grid = param_grid_case3, cv = 5)
grid.fit(x_val,y_val)
print(grid.best_params_)
print(grid.best_score_)

# %% [markdown]
# #**Randomized Search CV**

# %% [markdown]
# **Case 1**

# %%
base_learners = [
    ("svm", SVC(probability=True, random_state=42)),
    ("nb", GaussianNB()),
    ("dt", DecisionTreeClassifier(random_state=42))
]

final_estimator = LogisticRegression(max_iter=500, random_state=42)

model1 = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

'''param_grid_case1 = {
    # SVM
    "svm__C": [0.1, 1, 10],
    "svm__kernel": ["linear", "rbf"],
    "svm__gamma": ["scale", "auto"],

    # Naive Bayes
    "nb__var_smoothing": [1e-9, 1e-8, 1e-7],

    # Decision Tree
    "dt__max_depth": [None, 5, 10],
    "dt__criterion": ["gini", "entropy"],

    # Logistic Regression (final estimator)
    "final_estimator__C": [0.01, 0.1, 1, 10],
    "final_estimator__penalty": ["l1", "l2"],
    "final_estimator__solver": ["liblinear", "saga"]
}'''

param_grid_case1 = {
    "svm__C": [0.1, 1],
    "svm__kernel": ["linear", "rbf"],
    "svm__gamma": ["scale"],

    "nb__var_smoothing": [1e-9, 1e-8],

    "dt__max_depth": [None, 10],
    "dt__criterion": ["gini"],

    "final_estimator__C": [0.1, 1, 10],
    "final_estimator__penalty": ["l2"],
    "final_estimator__solver": ["liblinear"]
}

randomsearch = RandomizedSearchCV(model1,param_distributions = param_grid_case1, n_iter=10, cv = 5)
randomsearch.fit(x_val,y_val)
print(randomsearch.best_params_)
print(randomsearch.best_score_)

# %% [markdown]
# **Case 2**

# %%
final_estimator = RandomForestClassifier(random_state=42)

model2 = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

'''param_grid_case2 = {
    # SVM
    "svm__C": [0.1, 1, 10],
    "svm__kernel": ["linear", "rbf"],
    "svm__gamma": ["scale", "auto"],

    # Naive Bayes
    "nb__var_smoothing": [1e-9, 1e-8, 1e-7],

    # Decision Tree
    "dt__max_depth": [None, 5, 10],
    "dt__criterion": ["gini", "entropy"],

    # Random Forest (final estimator)
    "final_estimator__n_estimators": [100, 200, 500],
    "final_estimator__max_depth": [None, 10, 20],
    "final_estimator__min_samples_split": [2, 5, 10],
    "final_estimator__max_features": ["sqrt", "log2"]
}'''

param_grid_case2 = {
    "svm__C": [0.1, 1],
    "svm__kernel": ["rbf"],
    "svm__gamma": ["scale"],

    "nb__var_smoothing": [1e-9],

    "dt__max_depth": [None, 10],
    "dt__criterion": ["gini"],

    "final_estimator__n_estimators": [100, 300],
    "final_estimator__max_depth": [None, 20],
    "final_estimator__min_samples_split": [2, 5],
    "final_estimator__max_features": ["sqrt"]
}

randomsearch = RandomizedSearchCV(model2,param_distributions = param_grid_case2, n_iter=10, cv = 5)
randomsearch.fit(x_val,y_val)
print(randomsearch.best_params_)
print(randomsearch.best_score_)

# %% [markdown]
# **Case 3**

# %%
base_learners_case3 = [
    ("svm", SVC(probability=True, random_state=42)),
    ("dt", DecisionTreeClassifier(random_state=42)),
    ("knn", KNeighborsClassifier())
]

final_estimator = LogisticRegression(max_iter=500, random_state=42)

model3 = StackingClassifier(
    estimators=base_learners_case3,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

'''param_grid_case3 = {
    # SVM
    "svm__C": [0.1, 1, 10],
    "svm__kernel": ["linear", "rbf"],
    "svm__gamma": ["scale", "auto"],

    # Decision Tree
    "dt__max_depth": [None, 5, 10],
    "dt__criterion": ["gini", "entropy"],

    # KNN
    "knn__n_neighbors": [3, 5, 7, 11],
    "knn__weights": ["uniform", "distance"],
    "knn__metric": ["euclidean", "manhattan"],

    # Logistic Regression (final estimator)
    "final_estimator__C": [0.01, 0.1, 1, 10],
    "final_estimator__penalty": ["l1", "l2"],
    "final_estimator__solver": ["liblinear", "saga"]
}'''

param_grid_case3 = {
    "svm__C": [0.1, 1],
    "svm__kernel": ["rbf"],
    "svm__gamma": ["scale"],

    "dt__max_depth": [None, 10],
    "dt__criterion": ["gini"],

    "knn__n_neighbors": [5, 11],
    "knn__weights": ["uniform", "distance"],
    "knn__metric": ["euclidean"],

    "final_estimator__C": [0.1, 1],
    "final_estimator__penalty": ["l2"],
    "final_estimator__solver": ["liblinear"]
}

randomsearch = RandomizedSearchCV(model3,param_distributions = param_grid_case3, n_iter=10, cv = 5)
randomsearch.fit(x_val,y_val)
print(randomsearch.best_params_)
print(randomsearch.best_score_)

# %% [markdown]
# #**Testing**

# %% [markdown]
# # **(i) Model with Base Models as**
# * SVM
#
# * Na¨ıve Bayes
#
# * Decision Tree
#
# **and Final Estimator as Logistic Regression**

# %%
base_learners = [
    ("svm", SVC(probability=True, random_state=42)),
    ("nb", GaussianNB()),
    ("dt", DecisionTreeClassifier(random_state=42))
]

final_estimator = LogisticRegression(random_state=42)

model = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

model.fit(x_train,y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('svm', SVC(probability=True, random_state=42)),
#                                ('nb', GaussianNB()),
#                                ('dt', DecisionTreeClassifier(random_state=42))],
#                    final_estimator=LogisticRegression(random_state=42),
#                    n_jobs=-1)

# %%
y_pre_test = model.predict(x_test)

con_test_model = confusion_matrix(y_train,y_pre_train)
accuracy_model_test = accuracy_score(y_test,y_pre_test)
precision_model_test = precision_score(y_test,y_pre_test)
f1_model_test = f1_score(y_test,y_pre_test)
recall_model_test = recall_score(y_test,y_pre_test)

print("\nAccuracy Score of Testing  :",accuracy_model_test)
print("Precision Score of Testing :",precision_model_test)
print("F1 Score of Testing        :",f1_model_test)
print("Recall Score of Testing    :",recall_model_test)
print("\nConfusion Matrix :- \n",con_test_model)

sns.heatmap(con_test_model,annot=True,fmt='d')
plt.show()

y_probs_knn = model.predict_proba(x_test)[:, 1]
fpr_model, tpr_model, thresholds = roc_curve(y_test, y_probs_knn)
roc_auc_model = auc(fpr_model, tpr_model)

plt.figure(figsize=(8, 6))
plt.plot(fpr_model, tpr_model, color='b', label=f'ROC curve (area = {roc_auc_model:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (ROC) Curve for Random Forest Classifier')
plt.legend(loc='lower right')
plt.show()
# Out:
# Accuracy Score of Testing  : 0.8947368421052632
# Precision Score of Testing : 0.8
# F1 Score of Testing        : 0.8
# Recall Score of Testing    : 0.8
#
# Confusion Matrix :-
#  [[170   0]
#  [  0 114]]

# %% [markdown]
# # **(ii) Model with Base Models as**
# * SVM
# * Na¨ıve Bayes
# * Decision Tree
#
# **and Final Estimator as Random Forest**

# %%
base_learners = [
    ("svm", SVC(probability=True, random_state=42)),
    ("nb", GaussianNB()),
    ("dt", DecisionTreeClassifier(random_state=42))
]

final_estimator = RandomForestClassifier(random_state=42)

model = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

model.fit(x_train,y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('svm', SVC(probability=True, random_state=42)),
#                                ('nb', GaussianNB()),
#                                ('dt', DecisionTreeClassifier(random_state=42))],
#                    final_estimator=RandomForestClassifier(random_state=42),
#                    n_jobs=-1)

# %%
y_pre_test = model.predict(x_test)

con_test_model = confusion_matrix(y_train,y_pre_train)
accuracy_model_test = accuracy_score(y_test,y_pre_test)
precision_model_test = precision_score(y_test,y_pre_test)
f1_model_test = f1_score(y_test,y_pre_test)
recall_model_test = recall_score(y_test,y_pre_test)

print("\nAccuracy Score of Testing  :",accuracy_model_test)
print("Precision Score of Testing :",precision_model_test)
print("F1 Score of Testing        :",f1_model_test)
print("Recall Score of Testing    :",recall_model_test)
print("\nConfusion Matrix :- \n",con_test_model)

sns.heatmap(con_test_model,annot=True,fmt='d')
plt.show()

y_probs_knn = model.predict_proba(x_test)[:, 1]
fpr_model, tpr_model, thresholds = roc_curve(y_test, y_probs_knn)
roc_auc_model = auc(fpr_model, tpr_model)

plt.figure(figsize=(8, 6))
plt.plot(fpr_model, tpr_model, color='b', label=f'ROC curve (area = {roc_auc_model:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (ROC) Curve for Random Forest Classifier')
plt.legend(loc='lower right')
plt.show()
# Out:
# Accuracy Score of Testing  : 0.8947368421052632
# Precision Score of Testing : 0.8
# F1 Score of Testing        : 0.8
# Recall Score of Testing    : 0.8
#
# Confusion Matrix :-
#  [[170   0]
#  [  0 114]]

# %% [markdown]
# # **(iii) Model with Base Models as**
# * SVM
# * Decision Tree
# * KNN
#
# **and Final Estimator as Logistic Regression**

# %%
base_learners = [
    ("svm", SVC(probability=True, random_state=42)),
    ("nb", GaussianNB()),
    ("dt", KNeighborsClassifier())
]

final_estimator = LogisticRegression(random_state=42)

model = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

model.fit(x_train,y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('svm', SVC(probability=True, random_state=42)),
#                                ('nb', GaussianNB()),
#                                ('dt', KNeighborsClassifier())],
#                    final_estimator=LogisticRegression(random_state=42),
#                    n_jobs=-1)

# %%
y_pre_test = model.predict(x_test)

con_test_model = confusion_matrix(y_train,y_pre_train)
accuracy_model_test = accuracy_score(y_test,y_pre_test)
precision_model_test = precision_score(y_test,y_pre_test)
f1_model_test = f1_score(y_test,y_pre_test)
recall_model_test = recall_score(y_test,y_pre_test)

print("\nAccuracy Score of Testing  :",accuracy_model_test)
print("Precision Score of Testing :",precision_model_test)
print("F1 Score of Testing        :",f1_model_test)
print("Recall Score of Testing    :",recall_model_test)
print("\nConfusion Matrix :- \n",con_test_model)

sns.heatmap(con_test_model,annot=True,fmt='d')
plt.show()

y_probs_knn = model.predict_proba(x_test)[:, 1]
fpr_model, tpr_model, thresholds = roc_curve(y_test, y_probs_knn)
roc_auc_model = auc(fpr_model, tpr_model)

plt.figure(figsize=(8, 6))
plt.plot(fpr_model, tpr_model, color='b', label=f'ROC curve (area = {roc_auc_model:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (ROC) Curve for Random Forest Classifier')
plt.legend(loc='lower right')
plt.show()
# Out:
# Accuracy Score of Testing  : 0.7543859649122807
# Precision Score of Testing : 0.5714285714285714
# F1 Score of Testing        : 0.36363636363636365
# Recall Score of Testing    : 0.26666666666666666
#
# Confusion Matrix :-
#  [[170   0]
#  [  0 114]]

# %% [markdown]
# #**Cross validation**

# %% [markdown]
# # **(i) Model with Base Models as**
# * SVM
#
# * Na¨ıve Bayes
#
# * Decision Tree
#
# **and Final Estimator as Logistic Regression**

# %%
accuracy = []
precision = []
f1 = []
recall = []
area = []

base_learners = [
    ("svm", SVC(probability=True, random_state=42)),
    ("nb", GaussianNB()),
    ("dt", DecisionTreeClassifier(random_state=42))
]

final_estimator = LogisticRegression(random_state=42)

model = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

kf = KFold(n_splits=5,shuffle=True,random_state=42)

for train_index,test_index in kf.split(x):

  x_train,x_test = x_norm.iloc[train_index],x_norm.iloc[test_index]
  y_train,y_test = y.iloc[train_index],y.iloc[test_index]

  print("\n----- Fold ------")

  model.fit(x_train,y_train)
  y_pre_train = model.predict(x_train)
  con_train_model = confusion_matrix(y_train,y_pre_train)

  accuracy_model_train = accuracy_score(y_train,y_pre_train)
  precision_model_train = precision_score(y_train,y_pre_train)
  f1_model_train = f1_score(y_train,y_pre_train)
  recall_model_train = recall_score(y_train,y_pre_train)

  print("Accuracy Score of Training  :",accuracy_model_train)
  print("Precision Score of Training :",precision_model_train)
  print("F1 Score of Training        :",f1_model_train)
  print("Recall Score of Training    :",recall_model_train)
  print("\nConfusion Matrix :- \n",con_train_model)

  y_pre_test = model.predict(x_test)
  con_test_model = confusion_matrix(y_train,y_pre_train)

  accuracy_model_test = accuracy_score(y_test,y_pre_test)
  precision_model_test = precision_score(y_test,y_pre_test)
  f1_model_test = f1_score(y_test,y_pre_test)
  recall_model_test = recall_score(y_test,y_pre_test)

  accuracy.append(accuracy_model_test)
  precision.append(precision_model_test)
  f1.append(f1_model_test)
  recall.append(recall_model_test)

  print("\nAccuracy Score of Testing  :",accuracy_model_test)
  print("Precision Score of Testing :",precision_model_test)
  print("F1 Score of Testing        :",f1_model_test)
  print("Recall Score of Testing    :",recall_model_test)
  print("\nConfusion Matrix :- \n",con_test_model)

  sns.heatmap(con_test_model)
  plt.show()

  y_probs_model = model.predict_proba(x_test)[:, 1]
  fpr_model, tpr_model, thresholds = roc_curve(y_test, y_probs_model)
  roc_auc_model = auc(fpr_model, tpr_model)
  area.append(roc_auc_model)

  plt.figure(figsize=(8, 6))
  plt.plot(fpr_model, tpr_model, color='b', label=f'ROC curve (area = {roc_auc_model:.2f})')
  plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title(f'Receiver Operating Characteristic (ROC) Curve for Stacked Ensembled Model Classifier case 1')
  plt.legend(loc='lower right')
  plt.show()
# Out:
# ----- Fold ------
# Accuracy Score of Training  : 1.0
# Precision Score of Training : 1.0
# F1 Score of Training        : 1.0
# Recall Score of Training    : 1.0
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
#
# Accuracy Score of Testing  : 0.9385964912280702
# Precision Score of Testing : 0.9090909090909091
# F1 Score of Testing        : 0.9195402298850575
# Recall Score of Testing    : 0.9302325581395349
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
# ----- Fold ------
# Accuracy Score of Training  : 1.0
# Precision Score of Training : 1.0
# F1 Score of Training        : 1.0
# Recall Score of Training    : 1.0
#
# Confusion Matrix :-
#  [[280   0]
#  [  0 175]]
#
# Accuracy Score of Testing  : 0.9210526315789473
# Precision Score of Testing : 0.8888888888888888
# F1 Score of Testing        : 0.8767123287671232
# Recall Score of Testing    : 0.8648648648648649
#
# Confusion Matrix :-
#  [[280   0]
#  [  0 175]]
# ----- Fold ------
# Accuracy Score of Training  : 1.0
# Precision Score of Training : 1.0
# F1 Score of Training        : 1.0
# Recall Score of Training    : 1.0
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
#
# Accuracy Score of Testing  : 0.9122807017543859
# Precision Score of Testing : 0.9024390243902439
# F1 Score of Testing        : 0.8809523809523809
# Recall Score of Testing    : 0.8604651162790697
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
# ----- Fold ------
# Accuracy Score of Training  : 1.0
# Precision Score of Training : 1.0
# F1 Score of Training        : 1.0
# Recall Score of Training    : 1.0
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
#
# Accuracy Score of Testing  : 0.9649122807017544
# Precision Score of Testing : 0.9534883720930233
# F1 Score of Testing        : 0.9534883720930233
# Recall Score of Testing    : 0.9534883720930233
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
# ----- Fold ------
# Accuracy Score of Training  : 1.0
# Precision Score of Training : 1.0
# F1 Score of Training        : 1.0
# Recall Score of Training    : 1.0
#
# Confusion Matrix :-
#  [[290   0]
#  [  0 166]]
#
# Accuracy Score of Testing  : 0.9380530973451328
# Precision Score of Testing : 0.9534883720930233
# F1 Score of Testing        : 0.9213483146067416
# Recall Score of Testing    : 0.8913043478260869
#
# Confusion Matrix :-
#  [[290   0]
#  [  0 166]]

# %%
df = pd.DataFrame({
    'KFold': list(range(1, 6)),
    'accuracy': accuracy,
    'precision': precision,
    'f1': f1,
    'recall': recall,
    'auc': area
})

mean_row = pd.DataFrame([{
    'KFold': 'Mean',
    'accuracy': np.mean(accuracy),
    'precision': np.mean(precision),
    'f1': np.mean(f1),
    'recall': np.mean(recall),
    'auc': np.mean(area)
}])

df = pd.concat([df, mean_row], ignore_index=True)


print("K Fold for Stacked Ensembled Model Classifier case 1 :-\n")
df
# Out:
# K Fold for Stacked Ensembled Model Classifier case 1 :-
#   KFold  accuracy  precision        f1    recall       auc
# 0     1  0.938596   0.909091  0.919540  0.930233  0.913855
# 1     2  0.921053   0.888889  0.876712  0.864865  0.908389
# 2     3  0.912281   0.902439  0.880952  0.860465  0.946610
# 3     4  0.964912   0.953488  0.953488  0.953488  0.959384
# 4     5  0.938053   0.953488  0.921348  0.891304  0.973394
# 5  Mean  0.934979   0.921479  0.910408  0.900071  0.940326

# %% [markdown]
# # **(ii) Model with Base Models as**
# * SVM
# * Na¨ıve Bayes
# * Decision Tree
#
# **and Final Estimator as Random Forest**

# %%
accuracy = []
precision = []
f1 = []
recall = []
area = []

base_learners = [
    ("svm", SVC(probability=True, random_state=42)),
    ("nb", GaussianNB()),
    ("dt", DecisionTreeClassifier(random_state=42))
]

final_estimator = RandomForestClassifier(random_state=42)

model = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

kf = KFold(n_splits=5,shuffle=True,random_state=42)

for train_index,test_index in kf.split(x):

  x_train,x_test = x_norm.iloc[train_index],x_norm.iloc[test_index]
  y_train,y_test = y.iloc[train_index],y.iloc[test_index]

  print("\n----- Fold ------")

  model.fit(x_train,y_train)
  y_pre_train = model.predict(x_train)
  con_train_model = confusion_matrix(y_train,y_pre_train)

  accuracy_model_train = accuracy_score(y_train,y_pre_train)
  precision_model_train = precision_score(y_train,y_pre_train)
  f1_model_train = f1_score(y_train,y_pre_train)
  recall_model_train = recall_score(y_train,y_pre_train)

  print("Accuracy Score of Training  :",accuracy_model_train)
  print("Precision Score of Training :",precision_model_train)
  print("F1 Score of Training        :",f1_model_train)
  print("Recall Score of Training    :",recall_model_train)
  print("\nConfusion Matrix :- \n",con_train_model)

  y_pre_test = model.predict(x_test)
  con_test_model = confusion_matrix(y_train,y_pre_train)

  accuracy_model_test = accuracy_score(y_test,y_pre_test)
  precision_model_test = precision_score(y_test,y_pre_test)
  f1_model_test = f1_score(y_test,y_pre_test)
  recall_model_test = recall_score(y_test,y_pre_test)

  accuracy.append(accuracy_model_test)
  precision.append(precision_model_test)
  f1.append(f1_model_test)
  recall.append(recall_model_test)

  print("\nAccuracy Score of Testing  :",accuracy_model_test)
  print("Precision Score of Testing :",precision_model_test)
  print("F1 Score of Testing        :",f1_model_test)
  print("Recall Score of Testing    :",recall_model_test)
  print("\nConfusion Matrix :- \n",con_test_model)

  sns.heatmap(con_test_model)
  plt.show()

  y_probs_model = model.predict_proba(x_test)[:, 1]
  fpr_model, tpr_model, thresholds = roc_curve(y_test, y_probs_model)
  roc_auc_model = auc(fpr_model, tpr_model)
  area.append(roc_auc_model)

  plt.figure(figsize=(8, 6))
  plt.plot(fpr_model, tpr_model, color='b', label=f'ROC curve (area = {roc_auc_model:.2f})')
  plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title(f'Receiver Operating Characteristic (ROC) Curve for Stacked Ensembled Model Classifier case 2')
  plt.legend(loc='lower right')
  plt.show()
# Out:
# ----- Fold ------
# Accuracy Score of Training  : 1.0
# Precision Score of Training : 1.0
# F1 Score of Training        : 1.0
# Recall Score of Training    : 1.0
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
#
# Accuracy Score of Testing  : 0.9385964912280702
# Precision Score of Testing : 0.9090909090909091
# F1 Score of Testing        : 0.9195402298850575
# Recall Score of Testing    : 0.9302325581395349
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
# ----- Fold ------
# Accuracy Score of Training  : 1.0
# Precision Score of Training : 1.0
# F1 Score of Training        : 1.0
# Recall Score of Training    : 1.0
#
# Confusion Matrix :-
#  [[280   0]
#  [  0 175]]
#
# Accuracy Score of Testing  : 0.9210526315789473
# Precision Score of Testing : 0.8888888888888888
# F1 Score of Testing        : 0.8767123287671232
# Recall Score of Testing    : 0.8648648648648649
#
# Confusion Matrix :-
#  [[280   0]
#  [  0 175]]
# ----- Fold ------
# Accuracy Score of Training  : 1.0
# Precision Score of Training : 1.0
# F1 Score of Training        : 1.0
# Recall Score of Training    : 1.0
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
#
# Accuracy Score of Testing  : 0.9122807017543859
# Precision Score of Testing : 0.9024390243902439
# F1 Score of Testing        : 0.8809523809523809
# Recall Score of Testing    : 0.8604651162790697
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
# ----- Fold ------
# Accuracy Score of Training  : 1.0
# Precision Score of Training : 1.0
# F1 Score of Training        : 1.0
# Recall Score of Training    : 1.0
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
#
# Accuracy Score of Testing  : 0.9649122807017544
# Precision Score of Testing : 0.9534883720930233
# F1 Score of Testing        : 0.9534883720930233
# Recall Score of Testing    : 0.9534883720930233
#
# Confusion Matrix :-
#  [[286   0]
#  [  0 169]]
# ----- Fold ------
# Accuracy Score of Training  : 0.7675438596491229
# Precision Score of Training : 1.0
# F1 Score of Training        : 0.5309734513274337
# Recall Score of Training    : 0.3614457831325301
#
# Confusion Matrix :-
#  [[290   0]
#  [106  60]]
#
# Accuracy Score of Testing  : 0.6991150442477876
# Precision Score of Testing : 0.9285714285714286
# F1 Score of Testing        : 0.43333333333333335
# Recall Score of Testing    : 0.2826086956521739
#
# Confusion Matrix :-
#  [[290   0]
#  [106  60]]

# %%
df = pd.DataFrame({
    'KFold': list(range(1, 6)),
    'accuracy': accuracy,
    'precision': precision,
    'f1': f1,
    'recall': recall,
    'auc': area
})

mean_row = pd.DataFrame([{
    'KFold': 'Mean',
    'accuracy': np.mean(accuracy),
    'precision': np.mean(precision),
    'f1': np.mean(f1),
    'recall': np.mean(recall),
    'auc': np.mean(area)
}])

df = pd.concat([df, mean_row], ignore_index=True)


print("K Fold for Stacked Ensembled Model Classifier case 2 :-\n")
df
# Out:
# K Fold for Stacked Ensembled Model Classifier case 2 :-
#   KFold  accuracy  precision        f1    recall       auc
# 0     1  0.938596   0.909091  0.919540  0.930233  0.933344
# 1     2  0.921053   0.888889  0.876712  0.864865  0.903826
# 2     3  0.912281   0.902439  0.880952  0.860465  0.894366
# 3     4  0.964912   0.953488  0.953488  0.953488  0.967245
# 4     5  0.699115   0.928571  0.433333  0.282609  0.917099
# 5  Mean  0.887191   0.916496  0.812805  0.778332  0.923176

# %% [markdown]
# # **(iii) Model with Base Models as**
# * SVM
# * Decision Tree
# * KNN
#
# **and Final Estimator as Logistic Regression**

# %%
accuracy = []
precision = []
f1 = []
recall = []
area = []

base_learners = [
    ("svm", SVC(probability=True, random_state=42)),
    ("nb", GaussianNB()),
    ("dt", KNeighborsClassifier())
]

final_estimator = LogisticRegression(random_state=42)

model = StackingClassifier(
    estimators=base_learners,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

kf = KFold(n_splits=5,shuffle=True,random_state=42)

for train_index,test_index in kf.split(x):

  x_train,x_test = x_norm.iloc[train_index],x_norm.iloc[test_index]
  y_train,y_test = y.iloc[train_index],y.iloc[test_index]

  print("\n----- Fold ------")

  model.fit(x_train,y_train)
  y_pre_train = model.predict(x_train)
  con_train_model = confusion_matrix(y_train,y_pre_train)

  accuracy_model_train = accuracy_score(y_train,y_pre_train)
  precision_model_train = precision_score(y_train,y_pre_train)
  f1_model_train = f1_score(y_train,y_pre_train)
  recall_model_train = recall_score(y_train,y_pre_train)

  print("Accuracy Score of Training  :",accuracy_model_train)
  print("Precision Score of Training :",precision_model_train)
  print("F1 Score of Training        :",f1_model_train)
  print("Recall Score of Training    :",recall_model_train)
  print("\nConfusion Matrix :- \n",con_train_model)

  y_pre_test = model.predict(x_test)
  con_test_model = confusion_matrix(y_train,y_pre_train)

  accuracy_model_test = accuracy_score(y_test,y_pre_test)
  precision_model_test = precision_score(y_test,y_pre_test)
  f1_model_test = f1_score(y_test,y_pre_test)
  recall_model_test = recall_score(y_test,y_pre_test)

  accuracy.append(accuracy_model_test)
  precision.append(precision_model_test)
  f1.append(f1_model_test)
  recall.append(recall_model_test)

  print("\nAccuracy Score of Testing  :",accuracy_model_test)
  print("Precision Score of Testing :",precision_model_test)
  print("F1 Score of Testing        :",f1_model_test)
  print("Recall Score of Testing    :",recall_model_test)
  print("\nConfusion Matrix :- \n",con_test_model)

  sns.heatmap(con_test_model)
  plt.show()

  y_probs_model = model.predict_proba(x_test)[:, 1]
  fpr_model, tpr_model, thresholds = roc_curve(y_test, y_probs_model)
  roc_auc_model = auc(fpr_model, tpr_model)
  area.append(roc_auc_model)

  plt.figure(figsize=(8, 6))
  plt.plot(fpr_model, tpr_model, color='b', label=f'ROC curve (area = {roc_auc_model:.2f})')
  plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title(f'Receiver Operating Characteristic (ROC) Curve for Stacked Ensembled Model Classifier case 3')
  plt.legend(loc='lower right')
  plt.show()
# Out:
# ----- Fold ------
# Accuracy Score of Training  : 0.3010989010989011
# Precision Score of Training : 0.12562814070351758
# F1 Score of Training        : 0.1358695652173913
# Recall Score of Training    : 0.14792899408284024
#
# Confusion Matrix :-
#  [[112 174]
#  [144  25]]
#
# Accuracy Score of Testing  : 0.43859649122807015
# Precision Score of Testing : 0.2558139534883721
# F1 Score of Testing        : 0.2558139534883721
# Recall Score of Testing    : 0.2558139534883721
#
# Confusion Matrix :-
#  [[112 174]
#  [144  25]]
# ----- Fold ------
# Accuracy Score of Training  : 0.2967032967032967
# Precision Score of Training : 0.15311004784688995
# F1 Score of Training        : 0.16666666666666666
# Recall Score of Training    : 0.18285714285714286
#
# Confusion Matrix :-
#  [[103 177]
#  [143  32]]
#
# Accuracy Score of Testing  : 0.5087719298245614
# Precision Score of Testing : 0.32075471698113206
# F1 Score of Testing        : 0.37777777777777777
# Recall Score of Testing    : 0.4594594594594595
#
# Confusion Matrix :-
#  [[103 177]
#  [143  32]]
# ----- Fold ------
# Accuracy Score of Training  : 0.3054945054945055
# Precision Score of Training : 0.14492753623188406
# F1 Score of Training        : 0.1595744680851064
# Recall Score of Training    : 0.17751479289940827
#
# Confusion Matrix :-
#  [[109 177]
#  [139  30]]
#
# Accuracy Score of Testing  : 0.4649122807017544
# Precision Score of Testing : 0.3392857142857143
# F1 Score of Testing        : 0.3838383838383838
# Recall Score of Testing    : 0.4418604651162791
#
# Confusion Matrix :-
#  [[109 177]
#  [139  30]]
# ----- Fold ------
# Accuracy Score of Training  : 0.2725274725274725
# Precision Score of Training : 0.14782608695652175
# F1 Score of Training        : 0.17042606516290726
# Recall Score of Training    : 0.20118343195266272
#
# Confusion Matrix :-
#  [[ 90 196]
#  [135  34]]
#
# Accuracy Score of Testing  : 0.4473684210526316
# Precision Score of Testing : 0.3387096774193548
# F1 Score of Testing        : 0.4
# Recall Score of Testing    : 0.4883720930232558
#
# Confusion Matrix :-
#  [[ 90 196]
#  [135  34]]
# ----- Fold ------
# Accuracy Score of Training  : 0.30701754385964913
# Precision Score of Training : 0.12121212121212122
# F1 Score of Training        : 0.13186813186813187
# Recall Score of Training    : 0.14457831325301204
#
# Confusion Matrix :-
#  [[116 174]
#  [142  24]]
#
# Accuracy Score of Testing  : 0.45132743362831856
# Precision Score of Testing : 0.34615384615384615
# F1 Score of Testing        : 0.3673469387755102
# Recall Score of Testing    : 0.391304347826087
#
# Confusion Matrix :-
#  [[116 174]
#  [142  24]]

# %%
df = pd.DataFrame({
    'KFold': list(range(1, 6)),
    'accuracy': accuracy,
    'precision': precision,
    'f1': f1,
    'recall': recall,
    'auc': area
})

mean_row = pd.DataFrame([{
    'KFold': 'Mean',
    'accuracy': np.mean(accuracy),
    'precision': np.mean(precision),
    'f1': np.mean(f1),
    'recall': np.mean(recall),
    'auc': np.mean(area)
}])

df = pd.concat([df, mean_row], ignore_index=True)


print("K Fold for Stacked Ensembled Model Classifier case 3:-\n")
df
# Out:
# K Fold for Stacked Ensembled Model Classifier case 3:-
#   KFold  accuracy  precision        f1    recall       auc
# 0     1  0.438596   0.255814  0.255814  0.255814  0.348182
# 1     2  0.508772   0.320755  0.377778  0.459459  0.407862
# 2     3  0.464912   0.339286  0.383838  0.441860  0.367507
# 3     4  0.447368   0.338710  0.400000  0.488372  0.416639
# 4     5  0.451327   0.346154  0.367347  0.391304  0.396820
# 5  Mean  0.462195   0.320144  0.356955  0.407362  0.387402
